# %%
import os
import pandas as pd
import numpy as np
import sklearn
import kagglehub

# %% [markdown]
# ## Data and label grids

# %%
test_df = pd.read_csv("training_data.csv")

X_test =test_df.drop(columns=["target"])  #contiene i dati(input)
y_test = test_df["target"]  #contiene le label(risultati da verificare)
